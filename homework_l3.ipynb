# %% [markdown]
# # Домашнее задание после лекции 3

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Поменяйте тип данных переменной arms на "множетсво" и выведите получившееся значение. Это и будет ответом на задание.

# %%
arms = ["ARM A", "ARM B", "ARM B", "ARM C"]

# %% [markdown]
# ## Задание 2

# %% [markdown]
# У вас есть результат теста на глюкозу. Напишите программу которая будет узнавать если результат теста делится на 3 без остатка, то вывести вывести на экран "результат кратен трём". Иначе вывести на экран остаток от деления на 3. Примечание - В Python остаток от деления вычисляется с помощью оператора '%' (оператор модуля), например, 10 % 3 вернет 1. Ответом будет строка или остаток от деления.

# %%
gluc_result = 13

# %% [markdown]
# ## Задание 3

# %% [markdown]
# У вас есть список уровней сахара в крови у пациентов. Зная, что норма сахара в крови равна 6 - напишите программу которая найдёт средний показатель значения сахара в крови для пациентов у которых уровень сахара в крови выше нормы. Ответом будет одно число - средний уровень сахара округлённый до первого знака после запятой.

# %%
gluc_level = [5.5, 7.2, 6.0, 5.9, 7.4, 8.1, 4.0, 6.2, 5.5]
norm_gluc = 6.0

# %% [markdown]
# ## Задание 4

# %% [markdown]
# Предположим, у пациента с избыточным весом каждый день уменьшается масса тела на 0.3 кг. Напишите программу, которая будет отслеживать, сколько дней потребуется пациенту, чтобы достичь целевого веса (например, 75 кг). Начальный вес пациента — 85 кг. Ответом будет число дней.

# %%
patient_weight = 85
lost_every_day = 0.3
target_weight = 75
