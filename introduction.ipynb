# %% [markdown]
# # Введение в Python для медицинских данных

# %% [markdown]
# ## Первый код

# %%
print('Hello, medical world!')
# Out:
# Hello, medical world!

# %%
2+2
# Out:
# 4

# %%
4/2
# Out:
# 2.0

# %%
print(4)
# Out:
# 4

# %% [markdown]
# Медицинский пример

# %%
weight = 75

# %%
print(weight)
# Out:
# 70

# %%
weight = 70

# %%
height = 1.75
bmi = weight / height**2

# %%
print(bmi)
# Out:
# 22.857142857142858

# %%
bmi
# Out:
# 22.857142857142858

# %% [markdown]
# ![image.png](attachment:85b6ca23-8894-4646-ae83-2a72ff8b1236.png)
