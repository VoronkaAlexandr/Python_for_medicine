# %% [markdown]
# # Домашнее задание после лекции 5

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Пациента взвешивали и измеряли рост в течении месяца. Напишите функцию, которая принимает два аргумента: вес пациента в килограммах и его рост в метрах. На вход должны поступать два списка. Функция должна вычислять и возвращать средний индекс массы тела (ИМТ). Ответом должно быть число - средний индекс массы тела. Округлите число до второго знака после запятой. ИМТ считаем по формуле:

# %% [markdown]
# ![image.png](attachment:cac84bbe-50e9-4092-8062-d7b306ebfa08.png)

# %%
patient = {"USUBJID" : "1001-01", "WEIGHT" : [82, 80.5, 79, 80, 79.5], "HEIGHT" : [1.80, 1.80, 1.79, 1.80, 1.81]}

# %% [markdown]
# ## Задание 2

# %% [markdown]
# Для вычисления кривой выживаемости пациентов в клинических исследованиях вам необходимо написать функцию которая будет рассчитывать число днем между первым приёмом исследуемого препарата и первым днём "нежелательного явления". Используйте стандартую библиотеку datetime. В ответе должно быть число дней. Подсказка - при помощи datetime.datetime.strptime разбейте дату форматом "%d.%m.%Y" , а для вычтите из одной даты другую и используйте функцию .days на результате

# %%
import datetime
first_trt_day = "19.03.2015" # первый день приёма препарата
first_ae_day = "25.09.2015"  # первое появление "нежелательного явления"

# %% [markdown]
# ## Задание 3

# %% [markdown]
# Напишите программу, которая использует модуль statistics для вычисления статистических показателей на основе медицинских данных. Вам дан список возрастов пациентов в клиническом исследовании. При помощи модуля statistics посчитайте стандартное отклонение (подсказка - .stdev()) для списка. Ответом будет стандартное отклонение округлённое до второго знака после запятой

# %%
ages = [45, 60, 35, 70, 50, 55, 40]

# %% [markdown]
# ## Задание 4

# %% [markdown]
# Напишите класс Treatment который будет исходя из даты начала лечения, даты конца лечения и стоимости одного дня лечения возвращать цену за содержание пациента. Я частично уже написал class - можете им воспользоваться как основой и дописать недостающий код. Ответом будет число - стоимость лечения. Для рассчёта числа дней воспользуйтесь подсказкой из задания 2.

# %%
class Treatment:
    def __init__(self, start_date, end_date, daily_cost=0):
        #блок объявления атрибутов - тот же можно и разбить дату по формату

    def calculate_total_cost(self):
        return #формула для расчета стоимости лечения за все дни
        

# Использование:
treatment1 = Treatment("21.03.2015", "14.11.2015", 500)
treatment1.calculate_total_cost()
