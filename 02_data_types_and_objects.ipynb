# %% [markdown]
# # Лекция 2. Типы данных и объекты в Python

# %%
age = 45

# %%
patient_age = age

# %%
patient_age
# Out:
# 45

# %%
type(age)
# Out:
# int

# %%
age_one = 20
age_two = 30
age_three = 40

print(age_one, age_two, age_three)
# Out:
# 20 30 40

# %%
usubjidOne = 1
usubjidTwo = 2
usubjidThree = 3

print(usubjidOne, usubjidTwo, usubjidThree)
# Out:
# 1 2 3

# %%
usubjidоne = 1

# %%
usubjidone
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 usubjidone
#
# NameError: name 'usubjidone' is not defined

# %%
usubjid = "125"

# %%
usubjid / 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 usubjid / 5
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
125 / 5
# Out:
# 25.0

# %%
patientid_one = 1
patientid_two = 2

test_result_one = 0.25
test_result_two = 100.1

trt_name_one = "IC10"
trt_name_two = "IC11"

# %%
type(patientid_one + patientid_two)
# Out:
# int

# %%
type(test_result_one + test_result_two)
# Out:
# float

# %%
type(patientid_one + test_result_one)
# Out:
# float

# %%
trt_name_one + trt_name_two + trt_name_one + 'abc'
# Out:
# 'IC10IC11IC10abc'

# %%
trt_name_one + patientid_one
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 trt_name_one + patientid_one
#
# TypeError: can only concatenate str (not "int") to str

# %%
trt_name_one * 2
# Out:
# 'IC10IC10'

# %%
int("24") + 1
# Out:
# 25

# %%
result = 0.25
coef = 100
updated_result = int(result * coef)

# %%
updated_result
# Out:
# 25

# %%
int(25.6)
# Out:
# 25

# %%
round(25.6)
# Out:
# 26

# %%
lab_test_gluc = "3.5"
patient_number = "1000"

# %%
lab_test_gluc = float(lab_test_gluc) + 2
patient_number = int(patient_number) + 10

# %%
lab_test_gluc
# Out:
# 5.5

# %%
patient_number
# Out:
# 1010

# %%
usubjid = "ksc-1001-01"
int(usubjid)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 2
#       1 usubjid = "ksc-1001-01"
# ----> 2 int(usubjid)
#
# ValueError: invalid literal for int() with base 10: 'ksc-1001-01'

# %% [markdown]
# # Списки

# %%
ages = [45, 52, 60, 38, 70]

# %%
avg_ages = sum(ages) / len(ages)

# %%
avg_ages
# Out:
# 53.0

# %%
ages[0]
# Out:
# 45

# %%
ages[1]
# Out:
# 52

# %%
ages[-1]
# Out:
# 70

# %%
ages[-2]
# Out:
# 38

# %%
ages = ['45', [52, 21], 60, 38, 70]

# %%
ages[0]
# Out:
# '45'

# %%
ages[1][0]
# Out:
# 52

# %%
ages = [45, 52, 60, 38, 70]
ages[1:4]
# Out:
# [52, 60, 38]

# %%
ages[:4]
# Out:
# [45, 52, 60, 38]

# %%
ages[::2]
# Out:
# [45, 60, 70]

# %% [markdown]
# # Кортежи

# %%
bp = (120, 80)

# %%
systolic = bp[0]
diastolic = bp[1]

# %%
systolic
# Out:
# 120

# %%
bp[-1]
# Out:
# 80

# %%
bp[0:2]
# Out:
# (120, 80)

# %% [markdown]
# # Словари

# %%
patient = {"age":54, "sex":"F", "glucose":6.8, "treatment":"podorojnic"}

# %%
patient['age']
# Out:
# 54

# %%
patient.keys()
# Out:
# dict_keys(['age', 'sex', 'glucose', 'treatment'])

# %%
patient.values()
# Out:
# dict_values([54, 'F', 6.8, 'podorojnic'])

# %% [markdown]
# # Множества

# %%
trt_list = ['I10', 'E11', 'I10', 'J45']

# %%
trt_unique = set(trt_list)
trt_unique
# Out:
# {'E11', 'I10', 'J45'}

# %%
'I10' in trt_unique
# Out:
# True

# %%
'I11' in trt_unique
# Out:
# False

# %%
trt_unique.add('F12')
trt_unique
# Out:
# {'E11', 'F12', 'I10', 'J45'}

# %%
list(trt_unique)[0]
# Out:
# 'I10'

# %% [markdown]
# # Строки

# %%
diagnosis = "Гипертензия"

# %%
diagnosis.lower()
# Out:
# 'гипертензия'

# %%
diagnosis.upper()
# Out:
# 'ГИПЕРТЕНЗИЯ'

# %%
len(diagnosis)
# Out:
# 11

# %%
diagnosis[0]
# Out:
# 'Г'

# %%
diagnosis[-1]
# Out:
# 'я'

# %%
diagnosis[:3]
# Out:
# 'Гип'

# %%
diagnosis[::2]
# Out:
# 'Гпрезя'

# %% [markdown]
# # Преобразование данных

# %%
ages_list = [45, 52, 60]
ages_tuple = tuple(ages_list)
ages_tuple
# Out:
# (45, 52, 60)

# %%
bp_tuple = (120, 80)
bp_list = list(bp_tuple)
bp_list.append(75)
bp_list
# Out:
# [120, 80, 75]

# %%
trt_list = ['I10', 'E11', "I10", 'J45']
trt_unique = set(trt_list)
trt_unique
# Out:
# {'E11', 'I10', 'J45'}

# %%
trt_unique_sorted = list(trt_unique)
sorted(trt_unique_sorted)
# Out:
# ['E11', 'I10', 'J45']

# %%
patient = {"age":54, "sex":"F", "glucose":6.8, "treatment":"podorojnic"}
keys_list = list(patient.keys())

# %%
keys_list[0]
# Out:
# 'age'

# %%
values_list = list(patient.values())
values_list
# Out:
# [54, 'F', 6.8, 'podorojnic']
